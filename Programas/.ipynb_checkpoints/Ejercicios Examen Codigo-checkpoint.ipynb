# %% [markdown]
# # David Gamaliel Arcos Bravo
# ### Programas Calculo Numerico

# %% [markdown]
# ### Usa el método de Newton-Rapshon para encontrar la solución de
# ### x^3-2x^2-5=0
# ### En el intervalo [1,4].  Considera una aproximación inicial   x_0=2

# %%
Newton_Raphson(x0=2,f="x^3 - 2*x^2 - 5", show=True, step = 1)
# Out:
# Newton_Raphson
#
# Funcion Original: x^3 - 2*x^2 - 5   Derivada: 3*x**2 - 4*x
#    Iteración                 X_i                  F(x_i)       Err_abs  \
# 0          0                   2                      -5  5.000000e+00
# 1          1                3.25                8.203125  8.203125e+00
# 2          2   2.811036789297659      1.4087541771415921  1.408754e+00
# 3          3   2.697989502468529     0.08076844101196201  8.076844e-02
# 4          4  2.6906771528603617   0.0003254562850933951  3.254563e-04
# 5          5   2.690647448517619  5.3576165726099134e-09  5.357617e-09
# 6          6   2.690647448028614  1.7763568394002505e-15  1.776357e-15
#
#               Err_relativo
# 0                     100%
# 1                    62.5%
# 2      13.506560329302802%
# 3       4.021551310161781%
# 4      0.2710295796731999%
# 5   0.0011039727568681278%
# 6  1.8174244154243224e-08%
# Solucion: 2.690647448028614
# 2.690647448517619

# %% [markdown]
# ### Usa el método de bisección para encontrar la solución de
# ### x^4-2x^3-4x^2+4x+4=0
# ### En el intervalo [0,2]

# %%
Bisection(a=0, b=2, f="x^4 - 2*x^3 - 4*x^2 + 4*x + 4",show=True, step=1, eps = 0.0001)
# Out:
# Bisection
#
# Funcion: x^4 - 2*x^3 - 4*x^2 + 4*x + 4
# f(a): 4  ---  f(b): -4
#     Iteración      Left     Right       X_i                   F(x_i)  \
# 0           0  0.000000  2.000000  2.000000                       -4
# 1           1  1.000000  2.000000  1.000000                      3.0
# 2           2  1.000000  1.500000  1.500000                  -0.6875
# 3           3  1.250000  1.500000  1.250000               1.28515625
# 4           4  1.375000  1.500000  1.375000           0.312744140625
# 5           5  1.375000  1.437500  1.437500      -0.1865081787109375
# 6           6  1.406250  1.437500  1.406250       0.0636758804321289
# 7           7  1.406250  1.421875  1.421875     -0.06131833791732788
# 8           8  1.414062  1.421875  1.414062    0.0012084878981113434
# 9           9  1.414062  1.417969  1.417969    -0.030048150336369872
# 10         10  1.414062  1.416016  1.416016    -0.014418055521673523
# ...
