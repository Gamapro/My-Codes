# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# $ F(X,Y) = \sin(\frac{1}{2}x^2\ -\ \frac{1}{4}y^2\ +\ 3)\cos(2x\ +\ 1\ -\ e^y)$

# %%
f = lambda xy: np.sin((1/2)*(xy[0]**2) - (1/4)*(xy[1]**2) + 3)*np.cos(2*xy[0] + 1 - np.e**xy[1])
n = 100
X = np.linspace(-3,3,n)
Y = np.linspace(-3,3,n)

Z = np.zeros((n,n))

for ix,x in enumerate(X):
    for iy,y in enumerate(Y):
        Z[ix,iy] = f([x,y])
        
T = np.random.rand(2)*4 - 2
delta = 0.0001
lr = 0.001
grad = np.zeros(2)

plt.plot(T[0],T[1],'o',c='w')

for _i in range(10000):
    for i,v in enumerate(T):
        _T = np.copy(T)
        _T[i] = _T[i] + delta      # A la variable correspondiente le añado delta
        deriv=(f(_T)-f(T))/delta   # Calculo la derivada PARCIAL con la variable que estoy calculando   
        grad[i] = deriv            # Actualizo el valor del gradiente
    
    T = T - lr * grad
    if _i%1000 == 0:
        print(T,f(T))
    if _i%100 == 0:
        plt.plot(T[0],T[1],'.',c='r')
        

plt.contourf(X,Y,Z,80)
plt.colorbar()
plt.plot(T[0],T[1],'o',c='cyan')
plt.show()
# Out:
# [1.24161131 1.57153221] -0.0027996727330315435
# [2.00643942 1.59048948] -0.9400441884011649
# [2.18833067 1.68069506] -0.9996805562278468
# [2.20075371 1.68653996] -0.9999980385581567
# [2.20143859 1.68686127] -0.9999997487969439
# [2.20147588 1.68687877] -0.9999997941928653
# [2.20147791 1.68687972] -0.9999997965215541
# [2.20147802 1.68687977] -0.9999997966478424
# [2.20147803 1.68687977] -0.9999997966547126
# [2.20147803 1.68687977] -0.9999997966550864
